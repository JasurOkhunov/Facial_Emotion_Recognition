# %%
acc = [0.2582, 0.2790, 0.2832, 0.2982]
loss = [1.7257, 1.7127, 1.7010, 1.6883]

val_acc = [0.2767, 0.2400, 0.2492, 0.2517]
val_loss = [1.7395, 1.7713, 1.7639, 1.7629]

# %%
from matplotlib import pyplot as plt

plt.plot(list(range(1, 5)), acc, label='Training Accuracy')
plt.plot(list(range(1, 5)), val_acc, label='Validation Accuracy')
plt.xlabel("Training Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy for EfficientNetB7")
plt.legend()
plt.show()

# %%
acc = [0.4301, 0.5740, 0.6833, 0.7757, 0.8676, 0.9256, 0.9519, 0.9604, 0.9723, 0.9688]
loss = [1.4329, 1.0995, 0.8477, 0.6001, 0.3650, 0.2196, 0.1427, 0.1145, 0.0863, 0.0939]

val_acc = [0.1667, 0.2117, 0.4017, 0.4508, 0.5325, 0.5617, 0.5658, 0.5442, 0.5192, 0.5567]
val_loss = [1.9166, 1.7975, 1.5513, 1.6102, 1.5997, 1.5788, 1.7674, 1.8757, 1.9471, 2.2021]

# %%
plt.plot(list(range(1, len(acc) + 1)), acc, label='Training Accuracy')
plt.plot(list(range(1, len(acc) + 1)), val_acc, label='Validation Accuracy')
plt.xlabel("Training Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy for ResNet50")
plt.legend()
plt.show()

# %%
plt.plot(list(range(1, len(loss) + 1)), loss, label='Training Loss')
plt.plot(list(range(1, len(loss) + 1)), val_loss, label='Validation Loss')
plt.xlabel("Training Epoch")
plt.ylabel("Average Cross Entropy Loss")
plt.title("Training and Validation Loss for ResNet50")
plt.legend()
plt.show()

# %%
acc = [0.2496, 0.3675, 0.4280, 0.5032, 0.5552, 0.6129, 0.6477, 0.6854, 0.6911, 0.7291, 0.7416, 0.7457, 0.7548, 0.8030, 0.8395, 0.8524, 0.8708, 0.8911, 0.9189, 0.9040, 0.9214, 0.9180]
val_acc = [0.1667, 0.2708, 0.3575, 0.4303, 0.5092, 0.5408, 0.5458, 0.5542, 0.5601, 0.6133, 0.6335, 0.6472, 0.6689, 0.6640, 0.6620, 0.6697, 0.6779, 0.6953, 0.7163, 0.7287, 0.7486, 0.7720]

# %%
plt.plot(list(range(1, len(acc) + 1)), acc, label='Training Accuracy')
plt.plot(list(range(1, len(acc) + 1)), val_acc, label='Validation Accuracy')
plt.xlabel("Training Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy for VGG16")
plt.legend()
plt.show()

# %%
loss = [1.7238, 1.4441, 1.2739, 1.1708, 1.0877, 1.0042, 0.9179, 0.8323, 0.7759, 0.7302, 0.7079, 0.6837, 0.6605, 0.5460, 0.4759, 0.4323, 0.3950, 0.3569, 0.3247, 0.3361, 0.3014, 0.2604]
val_loss = [1.5977, 1.3629, 1.2566, 1.2314, 1.1464, 1.1198, 1.0055, 1.0912, 0.9404, 0.9071, 0.8717, 0.8445, 0.8126, 0.7745, 0.7359, 0.6123, 0.5720, 0.5940, 0.5597, 0.6230, 0.6899, 0.5925]

# %%
plt.plot(list(range(1, len(loss) + 1)), loss, label='Training Loss')
plt.plot(list(range(1, len(loss) + 1)), val_loss, label='Validation Loss')
plt.xlabel("Training Epoch")
plt.ylabel("Average Cross Entropy Loss")
plt.title("Training and Validation Loss for VGG16")
plt.legend()
plt.show()

# %%
# CustomNet
train_acc = [0.1897, 0.2083, 0.2856, 0.3038, 0.3367, 0.3673, 0.3792, 0.3987, 0.4009, 0.4076, 0.4202, 0.4281, 0.4312]
val_acc = [0.1667, 0.2072, 0.2116, 0.2381, 0.2471, 0.2681, 0.3164, 0.3340, 0.3450,  0.3896, 0.3916, 0.3409, 0.3512]


train_loss = [1.9898, 1.7204, 1.6078, 1.5945, 1.5408, 1.4609, 1.4208, 1.3989, 1.3578, 1.3098, 1.3129, 1.3111, 1.3049]
val_loss = [1.9560, 1.8240, 1.7990, 1.7004, 1.6714, 1.6558, 1.6375, 1.6361, 1.6444, 1.6432, 1.6458, 1.6897, 1.7237]

# %%
import matplotlib.pyplot as plt
plt.plot(list(range(1, len(train_acc) + 1)), train_acc, label='Training Accuracy')
plt.plot(list(range(1, len(train_acc) + 1)), val_acc, label='Validation Accuracy')
plt.xlabel("Training Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy for CustomNet")
plt.ylim(0, 1)
plt.legend()
plt.show()

# %%
plt.plot(list(range(1, len(val_loss) + 1)), train_loss, label='Training Loss')
plt.plot(list(range(1, len(val_loss) + 1)), val_loss, label='Validation Loss')
plt.xlabel("Training Epoch")
plt.ylabel("Average Cross Entropy Loss")
plt.title("Training and Validation Loss for CustomNet")
plt.legend()
plt.show()
